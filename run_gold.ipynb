# %%
import sys
import importlib
# Add path to engine files
sys.path.append("/Workspace/Shared/Capstone/Databricks")
import gold_engine
importlib.reload(gold_engine)
from gold_engine import GoldEngine

print("Starting Gold build")
engine = GoldEngine(spark)
engine.run()
