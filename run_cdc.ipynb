# %%
import sys

# Add path to engine files
sys.path.append("/Workspace/Shared/Capstone/Databricks")

from cdc_engine import CDCEngine


print("Starting CDC MERGE for live stream data")
engine = CDCEngine(spark)
engine.run()
